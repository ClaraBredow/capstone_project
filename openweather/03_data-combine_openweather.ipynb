# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import missingno as msno

# %%
# import pickle
df_sugarbeet = pd.read_pickle('data_strube/pickles/sugarbeet.pkl')
df_weather_monthly = pd.read_pickle('data_strube/pickles/df_openweather_monthly.pkl')

# %%
df_weather_monthly.columns
# Out:
# Index(['station_location', 'month', 'lat', 'lon', 'temp', 'dew_point',
#        'temp_min', 'temp_max', 'pressure', 'humidity', 'wind_speed',
#        'wind_deg', 'year', 'day', 'plotting_date'],
#       dtype='object')

# %%
# create lists of columns to include in different pivot tables
# long list for more complicated/detailed analysis, short list for baseline model
pivotvaluelist = ['temp', 'dew_point', 'temp_min',
       'temp_max', 'pressure', 'humidity', 'wind_speed', 'wind_deg']
simplepivotvaluelist = ['temp', 'temp_min','temp_max']

# %%
# make column name to str to facilitate flattening in the pivot dataframe later
df_weather_monthly.month = df_weather_monthly.month.astype(str)

# %%
# change dataframe shape from long to wide with pivot
df_weather_piv = pd.pivot(df_weather_monthly, index='station_location', columns=['month'], values=simplepivotvaluelist)

# %%
# flatten the multi-index columns
df_weather_piv.columns = ['_'.join(col) for col in df_weather_piv.columns.values]
#df_weather_piv.columns = ["_".join(tuple(map(str, t)))for t in df_weather_piv.columns.values]
# flatten all columns to one level
df_weather_piv.reset_index()
# Out:
#    station_location    temp_1    temp_10   temp_11   temp_12    temp_2  \
# 0            Anklam  1.086290  10.668239  6.711778  1.461263  0.793199
# 1           Bautzen  0.350430  10.487151  5.689181  2.380430  0.588661
# 2         Emmeloord  3.093602  11.768656  7.617889  4.790659  3.450461
# 3        Goderville  5.089247  12.667003  8.230681  7.390820  6.102351
# 4              Hamm  2.593978  11.493374  6.368931  4.804220  3.930818
# 5        Herchsheim  0.942527   9.359032  4.274792  3.488575  2.766696
# 6           Lamotte  3.072898  11.151721  6.216202  6.055119  4.798294
# 7          Lelystad  3.304086  11.907984  7.848056  5.257863  3.786399
# 8       Mattenkofen  0.104960   9.373602  3.872347  1.777218  2.598720
# 9    Oberviehhausen  0.007298   9.257863  3.850375  1.697298  2.598348
# 10       Pithiviers  4.060376  11.875739  5.827611  6.108602  6.365372
# 11            Soest  2.358414  11.314516  6.194764  4.579261  3.444554
# 12         Sommepy1  2.971250  10.848602  5.112639  5.358522  5.220580
# 13         Sommepy2  3.088629  10.732473  5.175625  5.470874  5.309747
# 14       Stadthagen  2.238644  11.481095  6.799031  4.464437  2.408289
# 15       Vierhoefen  0.214543   9.336882  3.840597  1.751277  2.708854
#
#       temp_3    temp_4     temp_5     temp_6  ...  temp_max_11  temp_max_12  \
# 0   4.675874  5.893292  11.360444  19.118833  ...     7.238194     2.184839
# 1   5.005376  6.322181  11.751667  20.137514  ...     6.646625     3.426196
# 2   6.371720  6.757444  11.166156  18.049931  ...     8.849764     6.147957
# 3   7.703804  7.248069  11.404610  15.709931  ...     9.322806     8.268159
print(f'the sugarbeet dataframe has {df_merge_monthly.shape[0]} rows and {df_merge_monthly.shape[1]} columns')
# Out:
# the sugarbeet dataframe has 16477 rows and 19 columns
# the sugarbeet dataframe has 16481 rows and 55 columns

# %%
df_merge_monthly.groupby(['station_location']).mean()
# Out:
#                   betaine_nir    cry_nir    csy_nir     dm_nir  invert_nir  \
# station_location
# Anklam               0.118164  60.410328  10.247223  21.789179    0.081215
# Bautzen              0.242435  68.591283  11.361550  22.157877    0.240900
# Emmeloord            0.120584  53.409332   8.488441  21.425727    0.171103
# Goderville           0.127166  61.337006  10.234917  22.277686    0.098934
# Hamm                      NaN        NaN        NaN        NaN         NaN
# Herchsheim           0.169137  67.267432  12.460393  23.914446    0.123959
# Lamotte              0.144019  74.656006  12.798154  23.559348    0.105824
# Lelystad             0.124812  63.954298  10.759825  22.246339    0.153983
# Mattenkofen          0.215736  77.811741  12.120567  20.601693    0.225379
# Oberviehhausen            NaN        NaN        NaN        NaN         NaN
# Pithiviers           0.258458  63.901938  12.391686  25.591748    0.258033
# Rittershausen        0.162424  58.814991  10.140035  22.894846    0.121691
# Soest                0.235797  71.048365  12.728119  23.260731    0.244613
# Sommepy              0.215190  62.943916  10.500440  22.375117    0.249811
# Sommepy1                  NaN        NaN        NaN        NaN         NaN
# Sommepy2                  NaN        NaN        NaN        NaN         NaN
# Stadthagen           0.186668  72.563920  14.096690  24.717821    0.095737
# Vierhoefen           0.198501  71.926561  10.196500  18.891185    0.245648
#
#                   mark_nir   ms_comp        obj  otype_comp  pollinator_comp  \
# station_location
# Anklam            4.815650  1.750357  30.583452    3.119829       567.205421
# Bautzen           5.584027  1.545833  34.495000    3.335000       682.448333
# Emmeloord         5.529328  1.550543  34.309942    3.335840       680.071011
# Goderville        5.639084  1.595777  34.677225    3.277526       653.582202
# Hamm                   NaN       NaN        NaN         NaN              NaN
# Herchsheim        5.409333  1.972973  28.797297    2.932432       345.770270
# Lamotte           6.406146  1.586317  33.578361    3.280032       663.757359
# Lelystad          5.413601  1.687825  32.760666    3.188345       628.330905
# Mattenkofen       5.034997  1.606965  34.491827    3.258706       639.106610
# Oberviehhausen         NaN       NaN        NaN         NaN              NaN
# Pithiviers        6.133372  1.590669  34.254449    3.305435       670.934103
# Rittershausen     5.655158  1.520619  34.987113    3.352234       692.488832
# Soest             5.326777  1.605024  33.330305    3.262961       644.691609
# Sommepy           5.693472  1.608352  34.411964    3.255079       637.085779
# Sommepy1               NaN       NaN        NaN         NaN              NaN
# Sommepy2               NaN       NaN        NaN         NaN              NaN
# Stadthagen        5.275677  1.608696  33.431835    3.276345       649.341931
# Vierhoefen        4.707784  1.621908  35.101296    3.254417       655.100118
#
#                   ...  temp_max_11  temp_max_12  temp_max_2  temp_max_3  \
# station_location  ...
# Anklam            ...     7.238194     2.184839    1.603988    5.276411
# Bautzen           ...     6.646625     3.426196    1.977396    6.276599
# Emmeloord         ...     8.849764     6.147957    5.066131    7.640806
# Goderville        ...     9.322806     8.268159    6.621607    8.307056
# Hamm              ...     7.355931     6.011613    5.512396    7.978078
# Herchsheim        ...     5.380792     4.536223    4.157604    6.727944
# Lamotte           ...     7.171774     6.719648    5.510742    7.714093
# Lelystad          ...     9.034625     6.541196    5.274509    7.783508
# Mattenkofen       ...     5.296792     3.491707    4.705685    6.795605
# Oberviehhausen    ...     5.067986     3.116210    4.535685    6.462016
# Pithiviers        ...     6.618153     6.784624    7.311756    8.472339
# Rittershausen     ...          NaN          NaN         NaN         NaN
# Soest             ...     7.140069     5.550927    5.045893    7.574718
# Sommepy           ...          NaN          NaN         NaN         NaN
# Sommepy1          ...     5.899847     5.963159    6.177455    7.427285
# Sommepy2          ...     6.001597     6.074597    6.287262    7.538911
# Stadthagen        ...     7.765145     5.563955    4.071513    7.398747
# Vierhoefen        ...     5.176583     3.635296    4.741265    6.770820
#
#                   temp_max_4  temp_max_5  temp_max_6  temp_max_7  temp_max_8  \
# station_location
# Anklam              6.614986   11.957876   19.913500   20.775511   16.992540
# Bautzen             7.571431   12.987890   21.662250   21.211680   18.444758
# Emmeloord           8.232750   12.522003   19.447611   19.624610   18.499140
# Goderville          7.955764   12.211546   17.106583   18.711210   17.602298
# Hamm                8.446819   12.921895   21.308403   19.986116   18.091129
# Herchsheim          8.310097   12.231129   21.051708   19.799032   18.063454
# Lamotte             7.805764   12.066378   18.262107   18.678823   17.365567
# Lelystad            8.378036   12.611210   19.565625   19.581465   18.508562
# Mattenkofen         9.356806   12.931277   21.612764   20.644704   18.551747
# Oberviehhausen      9.040264   12.953306   21.654958   20.601855   18.466142
# Pithiviers          9.991750   13.129583   20.079417   20.110403   19.360282
# Rittershausen            NaN         NaN         NaN         NaN         NaN
# Soest               8.047458   12.757419   21.044236   19.692661   18.118817
# Sommepy                  NaN         NaN         NaN         NaN         NaN
# Sommepy1            8.476000   12.145699   20.024542   19.014892   18.326895
# Sommepy2            8.575014   12.227796   19.982639   19.072594   18.323938
# Stadthagen          8.257747   13.134174   21.136607   20.684820   18.566039
# Vierhoefen          9.013375   13.018266   21.571639   20.648858   18.680417
#
#                   temp_max_9
# station_location
# Anklam             15.521389
# Bautzen            17.232097
# Emmeloord          17.533431
# Goderville         18.118556
# Hamm               17.063917
# Herchsheim         17.347361
# Lamotte            17.501563
# Lelystad           17.622875
# Mattenkofen        17.122111
# Oberviehhausen     16.971667
# Pithiviers         19.015028
# Rittershausen            NaN
# Soest              17.314403
# Sommepy                  NaN
# Sommepy1           17.561972
# Sommepy2           17.474167
# Stadthagen         17.335179
# Vierhoefen         17.268542
#
# [18 rows x 52 columns]

# %%
df_merge_monthly.isnull().sum()
# Out:
# betaine_nir            4
# cry_nir                4
# csy_nir                4
# dm_nir                 4
# fieldid                4
# region                 4
# invert_nir             4
# mark_nir               4
# ms_comp                4
# obj                    4
# otype_comp             4
# pollinator_comp        4
# sc_nir                 4
# seednames_coded        4
# seriesid               4
# totaln_nir             4
# x                      4
# y                      4
# station_location       0
# temp_1              2050
# temp_10             2050
# temp_11             2050
# temp_12             2050
# temp_2              2050
# temp_3              2050
# temp_4              2050
# temp_5              2050
# temp_6              2050
# temp_7              2050
# temp_8              2050
# temp_9              2050
# temp_min_1          2050
# temp_min_10         2050
# temp_min_11         2050
# temp_min_12         2050
# temp_min_2          2050
# temp_min_3          2050
# temp_min_4          2050
# temp_min_5          2050
# temp_min_6          2050
# temp_min_7          2050
# temp_min_8          2050
# temp_min_9          2050
# temp_max_1          2050
# temp_max_10         2050
# temp_max_11         2050
# temp_max_12         2050
# temp_max_2          2050
# temp_max_3          2050
# temp_max_4          2050
# temp_max_5          2050
# temp_max_6          2050
# temp_max_7          2050
# temp_max_8          2050
# temp_max_9          2050
# dtype: int64

# %%
locationdroplist = ['Hamm', 'Oberviehhausen', 'Sommepy1', 'Sommepy2']

# %%
# create a baseline model df with the core dates where we have weather data,
df_baseline_model = df_merge_monthly.drop(['temp_10', 'temp_11', 'temp_12', 'temp_1', 'temp_2', 'temp_3',
                                           'temp_max_10', 'temp_max_11', 'temp_max_12', 'temp_max_1', 'temp_max_2', 'temp_max_3',
                                           'temp_min_10', 'temp_min_11', 'temp_min_12', 'temp_min_1', 'temp_min_2', 'temp_min_3',],
                                           axis=1)

# %%
df_baseline_model.shape
# Out:
# (16481, 37)

# %%
df_baseline_model.station_location.unique()
# Out:
# array(['Emmeloord', 'Lelystad', 'Rittershausen', 'Sommepy', 'Herchsheim',
#        'Lamotte', 'Mattenkofen', 'Pithiviers', 'Vierhoefen', 'Bautzen',
#        'Stadthagen', 'Goderville', 'Soest', 'Anklam', 'Hamm',
#        'Oberviehhausen', 'Sommepy1', 'Sommepy2'], dtype=object)

# %%
# drop location with lots of missing values
df_baseline_model.drop(df_baseline_model[
    df_baseline_model.station_location
    .isin(locationdroplist)]
    .index, 
    axis=0, 
    inplace=True)
#df_baseline_model.drop(df_baseline_model.loc[df_baseline_model['station_location'].isin(locationdroplist)], inplace=True)

# %%
df_baseline_model.shape
# Out:
# (16477, 37)

# %%
df_baseline_model.station_location.unique()
# Out:
# array(['Emmeloord', 'Lelystad', 'Rittershausen', 'Sommepy', 'Herchsheim',
#        'Lamotte', 'Mattenkofen', 'Pithiviers', 'Vierhoefen', 'Bautzen',
#        'Stadthagen', 'Goderville', 'Soest', 'Anklam'], dtype=object)

# %%
df = df_baseline_model.dropna()

# %%
# PICKLE RICK
df.to_pickle('data_strube/pickles/baseline_model_openweather.pkl')
