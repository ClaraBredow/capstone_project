# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import missingno as msno

# %%
# import pickle
df_sugarbeet = pd.read_pickle('data/sugarbeet.pkl')
df_weather_monthly = pd.read_pickle('data/df_weatherstations_monthly.pkl')

# %%
df_sugarbeet.station_location.unique()
# Out:
# array(['Emmeloord', 'Lelystad', 'Rittershausen', 'Sommepy', 'Herchsheim',
#        'Lamotte', 'Mattenkofen', 'Pithiviers', 'Vierhoefen', 'Bautzen',
#        'Stadthagen', 'Goderville', 'Soest', 'Anklam'], dtype=object)

# %%
# reset index of weather frame
df_weather_monthly = df_weather_monthly.reset_index()
# drop index column created by step above
df_weather_monthly.drop(['index'], axis=1, inplace=True)

# %%
# create lists of columns to include in different pivot tables
# long list for more complicated/detailed analysis, short list for baseline model
pivotvaluelist = ['air_temperature_avg_monthly',
       'air_temperature_max_monthly', 'air_temperature_min_monthly',
       'eag_soil_moisture_1_monthly', 'eag_soil_moisture_2_monthly',
       'eag_soil_moisture_3_monthly', 'eag_soil_moisture_4_monthly',
       'eag_soil_moisture_5_monthly', 'eag_soil_moisture_6_monthly',
       'soil_salinity_1_monthly', 'soil_salinity_2_monthly',
       'soil_salinity_3_monthly', 'soil_salinity_4_monthly',
       'soil_salinity_5_monthly', 'soil_salinity_6_monthly',
       'soil_temperature_1_vg_monthly', 'soil_temperature_2_vg_monthly',
       'soil_temperature_3_vg_monthly', 'soil_temperature_4_vg_monthly',
       'soil_temperature_5_vg_monthly', 'soil_temperature_6_vg_monthly',
       'soil_temperature_1_min_monthly', 'soil_temperature_2_min_monthly',
       'soil_temperature_3_min_monthly', 'soil_temperature_4_min_monthly',
       'soil_temperature_5_min_monthly', 'soil_temperature_6_min_monthly',
       'soil_temperature_1_max_monthly', 'soil_temperature_2_max_monthly',
       'soil_temperature_3_max_monthly', 'soil_temperature_4_max_monthly',
       'soil_temperature_5_max_monthly', 'soil_temperature_6_max_monthly',
       'solar_radiation_monthly', 'relative_humidity_avg_monthly',
       'relative_humidity_max_monthly', 'relative_humidity_min_monthly',
       'precipitation_monthly', 'leaf_wetness_monthly']
simplepivotvaluelist = ['air_temperature_avg_monthly', 'air_temperature_max_monthly', 'air_temperature_min_monthly']

# %%
# make column name to str to facilitate flattening in the pivot dataframe later
df_weather_monthly.month = df_weather_monthly.month.astype(str)

# %%
# change dataframe shape from long to wide with pivot
df_weather_piv = pd.pivot(df_weather_monthly, index='station_location', columns=['month'], values=simplepivotvaluelist)

# %%
# flatten the multi-index columns
df_weather_piv.columns = ['_'.join(col) for col in df_weather_piv.columns.values]
#df_weather_piv.columns = ["_".join(tuple(map(str, t)))for t in df_weather_piv.columns.values]
# flatten all columns to one level
df_weather_piv.reset_index()
# Out:
#    station_location  air_temperature_avg_monthly_10  \
# 0            Anklam                       10.007846
# 1           Bautzen                             NaN
# 2        Berklingen                             NaN
# 3         Emmeloord                             NaN
# 4         Groningen                             NaN
# 5      Herchsheim 1                       10.005588
# 6           Lamotte                       11.142928
# 7          Lelystad                             NaN
# 8       Mattenkofen                             NaN
# 9             Peine                       11.048023
# 10            Soest                       11.358895
# 11          Sommepy                             NaN
# 12       Stadthagen                       11.040390
# 13        Söllingen                        9.851858
#
#     air_temperature_avg_monthly_11  air_temperature_avg_monthly_3  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# 5                              NaN                            NaN
# 6                              NaN                            NaN
# 7                              NaN                            NaN
# 8                              NaN                      12.723636
# 9                              NaN                            NaN
# 10                             NaN                            NaN
# 11                             NaN                            NaN
# 12                        7.492266                            NaN
# 13                             NaN                            NaN
#
#     air_temperature_avg_monthly_4  air_temperature_avg_monthly_5  \
# 0                        6.613427                      11.336505
# 1                       11.117188                      11.611196
# 2                        5.770699                      11.239247
# 3                        7.942705                      11.173804
# 4                        7.490939                      10.235892
# 5                        8.044080                      11.056371
# 6                        9.624444                      11.654073
# 7                             NaN                            NaN
# 8                        7.009264                      11.391723
# 9                        7.849278                      11.726720
# 10                       8.441000                      11.798199
# 11                       9.167363                      10.943280
# 12                       7.948444                      11.432675
# 13                       7.510267                      11.534677
#
#     air_temperature_avg_monthly_6  air_temperature_avg_monthly_7  \
# 0                       19.068611                      19.058535
# 1                       16.587822                            NaN
# 2                       18.984361                      18.554449
# 3                       17.907889                      17.906169
# 4                             NaN                            NaN
# 5                       19.320847                      17.790497
# 6                       17.851292                      18.367688
# 7                       17.817029                      17.844368
# 8                       19.779389                      18.421949
# 9                       19.580667                      18.564933
# 10                      19.368833                      18.222218
# 11                      18.159278                      17.787688
# 12                      19.023333                      18.447782
# 13                      19.285042                      18.466788
#
#     air_temperature_avg_monthly_8  air_temperature_avg_monthly_9  ...  \
# 0                       15.815605                      14.945822  ...
# 1                             NaN                            NaN  ...
# 2                       16.557513                      13.525556  ...
# 3                       16.754032                      15.992228  ...
# 4                             NaN                            NaN  ...
# 5                       16.541895                      15.200209  ...
# 6                       17.027594                      16.756444  ...
# 7                       16.813495                      16.812764  ...
# 8                       16.712661                      14.927701  ...
# 9                       16.745148                      15.152253  ...
# 10                      16.632903                      15.173241  ...
# 11                      16.970430                      16.898977  ...
# 12                      16.692245                      15.261838  ...
# 13                      16.443831                      15.221015  ...
#
#     air_temperature_max_monthly_9  air_temperature_min_monthly_10  \
# 0                       15.446769                        9.585241
# 1                             NaN                             NaN
# 2                       13.765556                             NaN
# 3                       16.535924                             NaN
# 4                             NaN                             NaN
# 5                       15.914576                        9.281176
# 6                       17.359219                       10.635168
# 7                       17.364327                             NaN
# 8                       15.654861                             NaN
# 9                       15.674117                       10.507450
# 10                      15.789235                       10.857305
# 11                      17.571062                             NaN
# 12                      15.839847                       10.543414
# 13                      15.789124                        9.315433
#
#     air_temperature_min_monthly_11  air_temperature_min_monthly_3  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# 5                              NaN                            NaN
# 6                              NaN                            NaN
# 7                              NaN                            NaN
# 8                              NaN                      11.751212
# 9                              NaN                            NaN
# 10                             NaN                            NaN
# 11                             NaN                            NaN
# 12                        7.110108                            NaN
# 13                             NaN                            NaN
#
#     air_temperature_min_monthly_4  air_temperature_min_monthly_5  \
# 0                        6.057263                      10.793441
# 1                       10.467187                      11.034355
# 2                        5.182568                      10.644610
# 3                        7.477295                      10.757823
# 4                        6.990884                       9.812649
# 5                        7.453520                      10.447796
# 6                        8.987778                      10.985780
# 7                             NaN                            NaN
# 8                        6.350958                      10.854576
# 9                        7.227056                      11.184261
# 10                       7.837813                      11.249167
# 11                       8.292418                      10.278992
# 12                       7.273000                      10.894852
# 13                       6.853667                      10.938683
#
#     air_temperature_min_monthly_6  air_temperature_min_monthly_7  \
# 0                       18.454750                      18.436196
# 1                       15.829406                            NaN
# 2                       18.392597                      17.970605
# 3                       17.443014                      17.403562
# 4                             NaN                            NaN
# 5                       18.705764                      17.120618
# 6                       17.283694                      17.771478
# 7                       17.361868                      17.362796
# 8                       19.080792                      17.764489
# 9                       19.007208                      17.975417
# 10                      18.777694                      17.602285
# 11                      17.537778                      17.213656
# 12                      18.447444                      17.820860
# 13                      18.708625                      17.882446
#
#     air_temperature_min_monthly_8  air_temperature_min_monthly_9
# 0                       15.209852                      14.468329
# 1                             NaN                            NaN
# 2                       15.950027                      13.306667
# 3                       16.251855                      15.461739
# 4                             NaN                            NaN
# 5                       15.877473                      14.504103
# 6                       16.411183                      16.168773
# 7                       16.319583                      16.256364
# 8                       16.079005                      14.223997
# 9                       16.159005                      14.652573
# 10                      16.027500                      14.577942
# 11                      16.362245                      16.229575
# 12                      16.080712                      14.692103
# 13                      15.816653                      14.665438
#
# [14 rows x 28 columns]

# %%
# merge sugar beet dataframe with the monthly weather info
df_merge_monthly = df_sugarbeet.merge(df_weather_piv, 
                                      on='station_location',
                                      how='outer')

# %%
# compare shapes of original and new merge dataframe
# --> we gained some rows
print(f'the sugarbeet dataframe has {df_sugarbeet.shape[0]} rows and {df_sugarbeet.shape[1]} columns')
print(f'the sugarbeet dataframe has {df_merge_monthly.shape[0]} rows and {df_merge_monthly.shape[1]} columns')
# Out:
# the sugarbeet dataframe has 16477 rows and 19 columns
# the sugarbeet dataframe has 16482 rows and 46 columns

# %%
df_merge_monthly.groupby(['station_location']).mean()
# Out:
# /var/folders/r8/96vp6rrx3633scm80v59y52c0000gn/T/ipykernel_2960/4228447699.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_merge_monthly.groupby(['station_location']).mean()
#                   betaine_nir    cry_nir    csy_nir     dm_nir  invert_nir  \
# station_location
# Anklam               0.118164  60.410328  10.247223  21.789179    0.081215
# Bautzen              0.242435  68.591283  11.361550  22.157877    0.240900
# Berklingen                NaN        NaN        NaN        NaN         NaN
# Emmeloord            0.120584  53.409332   8.488441  21.425727    0.171103
# Goderville           0.127166  61.337006  10.234917  22.277686    0.098934
# Groningen                 NaN        NaN        NaN        NaN         NaN
# Herchsheim           0.169137  67.267432  12.460393  23.914446    0.123959
# Herchsheim 1              NaN        NaN        NaN        NaN         NaN
# Lamotte              0.144019  74.656006  12.798154  23.559348    0.105824
# Lelystad             0.124812  63.954298  10.759825  22.246339    0.153983
# Mattenkofen          0.215736  77.811741  12.120567  20.601693    0.225379
# Peine                     NaN        NaN        NaN        NaN         NaN
# Pithiviers           0.258458  63.901938  12.391686  25.591748    0.258033
# Rittershausen        0.162424  58.814991  10.140035  22.894846    0.121691
# Soest                0.235797  71.048365  12.728119  23.260731    0.244613
# Sommepy              0.215190  62.943916  10.500440  22.375117    0.249811
# Stadthagen           0.186668  72.563920  14.096690  24.717821    0.095737
# Söllingen                 NaN        NaN        NaN        NaN         NaN
# Vierhoefen           0.198501  71.926561  10.196500  18.891185    0.245648
#
#                   mark_nir   ms_comp        obj  otype_comp  pollinator_comp  \
# station_location
# Anklam            4.815650  1.750357  30.583452    3.119829       567.205421
# Bautzen           5.584027  1.545833  34.495000    3.335000       682.448333
# Berklingen             NaN       NaN        NaN         NaN              NaN
# Emmeloord         5.529328  1.550543  34.309942    3.335840       680.071011
# Goderville        5.639084  1.595777  34.677225    3.277526       653.582202
# Groningen              NaN       NaN        NaN         NaN              NaN
# Herchsheim        5.409333  1.972973  28.797297    2.932432       345.770270
# Herchsheim 1           NaN       NaN        NaN         NaN              NaN
# Lamotte           6.406146  1.586317  33.578361    3.280032       663.757359
# Lelystad          5.413601  1.687825  32.760666    3.188345       628.330905
# Mattenkofen       5.034997  1.606965  34.491827    3.258706       639.106610
# Peine                  NaN       NaN        NaN         NaN              NaN
# Pithiviers        6.133372  1.590669  34.254449    3.305435       670.934103
# Rittershausen     5.655158  1.520619  34.987113    3.352234       692.488832
# Soest             5.326777  1.605024  33.330305    3.262961       644.691609
# Sommepy           5.693472  1.608352  34.411964    3.255079       637.085779
# Stadthagen        5.275677  1.608696  33.431835    3.276345       649.341931
# Söllingen              NaN       NaN        NaN         NaN              NaN
# Vierhoefen        4.707784  1.621908  35.101296    3.254417       655.100118
#
#                   ...  air_temperature_max_monthly_9  \
# station_location  ...
# Anklam            ...                      15.446769
# Bautzen           ...                            NaN
# Berklingen        ...                      13.765556
# Emmeloord         ...                      16.535924
# Goderville        ...                            NaN
# Groningen         ...                            NaN
# Herchsheim        ...                            NaN
# Herchsheim 1      ...                      15.914576
# Lamotte           ...                      17.359219
# Lelystad          ...                      17.364327
# Mattenkofen       ...                      15.654861
# Peine             ...                      15.674117
# Pithiviers        ...                            NaN
# Rittershausen     ...                            NaN
# Soest             ...                      15.789235
# Sommepy           ...                      17.571062
# Stadthagen        ...                      15.839847
# Söllingen         ...                      15.789124
# Vierhoefen        ...                            NaN
#
#                   air_temperature_min_monthly_10  \
# station_location
# Anklam                                  9.585241
# Bautzen                                      NaN
# Berklingen                                   NaN
# Emmeloord                                    NaN
# Goderville                                   NaN
# Groningen                                    NaN
# Herchsheim                                   NaN
# Herchsheim 1                            9.281176
# Lamotte                                10.635168
# Lelystad                                     NaN
# Mattenkofen                                  NaN
# Peine                                  10.507450
# Pithiviers                                   NaN
# Rittershausen                                NaN
# Soest                                  10.857305
# Sommepy                                      NaN
# Stadthagen                             10.543414
# Söllingen                               9.315433
# Vierhoefen                                   NaN
#
#                   air_temperature_min_monthly_11  \
# station_location
# Anklam                                       NaN
# Bautzen                                      NaN
# Berklingen                                   NaN
# Emmeloord                                    NaN
# Goderville                                   NaN
# Groningen                                    NaN
# Herchsheim                                   NaN
# Herchsheim 1                                 NaN
# Lamotte                                      NaN
# Lelystad                                     NaN
# Mattenkofen                                  NaN
# Peine                                        NaN
# Pithiviers                                   NaN
# Rittershausen                                NaN
# Soest                                        NaN
# Sommepy                                      NaN
# Stadthagen                              7.110108
# Söllingen                                    NaN
# Vierhoefen                                   NaN
#
#                   air_temperature_min_monthly_3  \
# station_location
# Anklam                                      NaN
# Bautzen                                     NaN
# Berklingen                                  NaN
# Emmeloord                                   NaN
# Goderville                                  NaN
# Groningen                                   NaN
# Herchsheim                                  NaN
# Herchsheim 1                                NaN
# Lamotte                                     NaN
# Lelystad                                    NaN
# Mattenkofen                           11.751212
# Peine                                       NaN
# Pithiviers                                  NaN
# Rittershausen                               NaN
# Soest                                       NaN
# Sommepy                                     NaN
# Stadthagen                                  NaN
# Söllingen                                   NaN
# Vierhoefen                                  NaN
#
#                   air_temperature_min_monthly_4  \
# station_location
# Anklam                                 6.057263
# Bautzen                               10.467187
# Berklingen                             5.182568
# Emmeloord                              7.477295
# Goderville                                  NaN
# Groningen                              6.990884
# Herchsheim                                  NaN
# Herchsheim 1                           7.453520
# Lamotte                                8.987778
# Lelystad                                    NaN
# Mattenkofen                            6.350958
# Peine                                  7.227056
# Pithiviers                                  NaN
# Rittershausen                               NaN
# Soest                                  7.837813
# Sommepy                                8.292418
# Stadthagen                             7.273000
# Söllingen                              6.853667
# Vierhoefen                                  NaN
#
#                   air_temperature_min_monthly_5  \
# station_location
# Anklam                                10.793441
# Bautzen                               11.034355
# Berklingen                            10.644610
# Emmeloord                             10.757823
# Goderville                                  NaN
# Groningen                              9.812649
# Herchsheim                                  NaN
# Herchsheim 1                          10.447796
# Lamotte                               10.985780
# Lelystad                                    NaN
# Mattenkofen                           10.854576
# Peine                                 11.184261
# Pithiviers                                  NaN
# Rittershausen                               NaN
# Soest                                 11.249167
# Sommepy                               10.278992
# Stadthagen                            10.894852
# Söllingen                             10.938683
# Vierhoefen                                  NaN
#
#                   air_temperature_min_monthly_6  \
# station_location
# Anklam                                18.454750
# Bautzen                               15.829406
# Berklingen                            18.392597
# Emmeloord                             17.443014
# Goderville                                  NaN
# Groningen                                   NaN
# Herchsheim                                  NaN
# Herchsheim 1                          18.705764
# Lamotte                               17.283694
# Lelystad                              17.361868
# Mattenkofen                           19.080792
# Peine                                 19.007208
# Pithiviers                                  NaN
# Rittershausen                               NaN
# Soest                                 18.777694
# Sommepy                               17.537778
# Stadthagen                            18.447444
# Söllingen                             18.708625
# Vierhoefen                                  NaN
#
#                   air_temperature_min_monthly_7  \
# station_location
# Anklam                                18.436196
# Bautzen                                     NaN
# Berklingen                            17.970605
# Emmeloord                             17.403562
# Goderville                                  NaN
# Groningen                                   NaN
# Herchsheim                                  NaN
# Herchsheim 1                          17.120618
# Lamotte                               17.771478
# Lelystad                              17.362796
# Mattenkofen                           17.764489
# Peine                                 17.975417
# Pithiviers                                  NaN
# Rittershausen                               NaN
# Soest                                 17.602285
# Sommepy                               17.213656
# Stadthagen                            17.820860
# Söllingen                             17.882446
# Vierhoefen                                  NaN
#
#                   air_temperature_min_monthly_8  air_temperature_min_monthly_9
# station_location
# Anklam                                15.209852                      14.468329
# Bautzen                                     NaN                            NaN
# Berklingen                            15.950027                      13.306667
# Emmeloord                             16.251855                      15.461739
# Goderville                                  NaN                            NaN
# Groningen                                   NaN                            NaN
# Herchsheim                                  NaN                            NaN
# Herchsheim 1                          15.877473                      14.504103
# Lamotte                               16.411183                      16.168773
# Lelystad                              16.319583                      16.256364
# Mattenkofen                           16.079005                      14.223997
# Peine                                 16.159005                      14.652573
# Pithiviers                                  NaN                            NaN
# Rittershausen                               NaN                            NaN
# Soest                                 16.027500                      14.577942
# Sommepy                               16.362245                      16.229575
# Stadthagen                            16.080712                      14.692103
# Söllingen                             15.816653                      14.665438
# Vierhoefen                                  NaN                            NaN
#
# [19 rows x 43 columns]

# %%
df_merge_monthly.isnull().sum()
# Out:
# betaine_nir                           5
# cry_nir                               5
# csy_nir                               5
# dm_nir                                5
# fieldid                               5
# region                                5
# invert_nir                            5
# mark_nir                              5
# ms_comp                               5
# obj                                   5
# otype_comp                            5
# pollinator_comp                       5
# sc_nir                                5
# seednames_coded                       5
# seriesid                              5
# totaln_nir                            5
# x                                     5
# y                                     5
# station_location                      0
# air_temperature_avg_monthly_10    11293
# air_temperature_avg_monthly_11    15125
# air_temperature_avg_monthly_3     15075
# air_temperature_avg_monthly_4      6601
# air_temperature_avg_monthly_5      6601
# air_temperature_avg_monthly_6      5641
# air_temperature_avg_monthly_7      6841
# air_temperature_avg_monthly_8      6841
# air_temperature_avg_monthly_9      6841
# air_temperature_max_monthly_10    11293
# air_temperature_max_monthly_11    15125
# air_temperature_max_monthly_3     15075
# air_temperature_max_monthly_4      6601
# air_temperature_max_monthly_5      6601
# air_temperature_max_monthly_6      5641
# air_temperature_max_monthly_7      6841
# air_temperature_max_monthly_8      6841
# air_temperature_max_monthly_9      6841
# air_temperature_min_monthly_10    11293
# air_temperature_min_monthly_11    15125
# air_temperature_min_monthly_3     15075
# air_temperature_min_monthly_4      6601
# air_temperature_min_monthly_5      6601
# air_temperature_min_monthly_6      5641
# air_temperature_min_monthly_7      6841
# air_temperature_min_monthly_8      6841
# air_temperature_min_monthly_9      6841
# dtype: int64

# %%
df_merge_monthly.air_temperature_avg_monthly_6
# Out:
# 0        17.907889
# 1        17.907889
# 2        17.907889
# 3        17.907889
# 4        17.907889
#            ...
# 16477    18.984361
# 16478          NaN
# 16479    19.320847
# 16480    19.580667
# 16481    19.285042
# Name: air_temperature_avg_monthly_6, Length: 16482, dtype: float64

# %%
locationdroplist = ['Berklingen', 'Groningen', 'Herchsheim 1', 'Peine', 'Söllingen', 'Bautzen', 'Lamotte', 'Lelystad', 'Rittershausen']

# %%
# create a baseline model df with the core dates where we have weather data,
df_baseline_model = df_merge_monthly.drop(['air_temperature_avg_monthly_10', 'air_temperature_avg_monthly_11', 'air_temperature_avg_monthly_3',
                                           'air_temperature_max_monthly_10', 'air_temperature_max_monthly_11', 'air_temperature_max_monthly_3',
                                           'air_temperature_min_monthly_10', 'air_temperature_min_monthly_11', 'air_temperature_min_monthly_3'],
                                           axis=1)

# %%
# drop location with lots of missing values
df_baseline_model.drop(df_baseline_model[
    df_baseline_model.station_location
    .isin(locationdroplist)]
    .index, 
    axis=0, 
    inplace=True)
#df_baseline_model.drop(df_baseline_model.loc[df_baseline_model['station_location'].isin(locationdroplist)], inplace=True)

# %%
df_baseline_model.shape
# Out:
# (11895, 37)

# %%
df_baseline_model.dropna(inplace=True)
df_baseline_model.station_location.unique()
# Out:
# array(['Emmeloord', 'Sommepy', 'Mattenkofen', 'Stadthagen', 'Soest',
#        'Anklam'], dtype=object)

# %%
df_baseline_model.shape
# Out:
# (7419, 37)

# %%
df_baseline_model.to_pickle('data/baseline_model.pkl')
